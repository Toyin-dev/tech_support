# %%
import os
os.chdir(r"C:/Users/OLA/Desktop/MACHINE LEARNING/unsupervisd learning k-clustering/tech_support")
os.getcwd()

# %%
# %%writefile .gitignore
# .ipynb_checkpoints/

# %%
# !git init

# %%
# !git remote add origin https://github.com/Toyin-dev/tech_support.git

# %%
# !git add .
# !git commit -m "Add Technical Support ML dataset"
# !git push -u origin

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("technical_support_data-2.csv")
df
# Out:
#                                  PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0             Temperature control not working          170                1.3
# 1            power chord does not tightly fit           12                2.0
# 2                       Fan swing not working            5                1.0
# 3                     Main switch does not on            3                2.0
# 4                  Forgot mobile app password           45                2.3
# 5                           AC stops abruptly           47                3.1
# 6            App hangs while entring commands           12                4.0
# 7         App takes a long time to initialize          165                1.2
# 8     Unable to connect the App to the device          321                1.0
# 9        Reinstalling the app hangs the phone           22                3.3
# 10       Mobile screen blanks on use of phone           23                4.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PROBLEM_TYPE           23 non-null     object
#  1   no_of_cases            23 non-null     int64
#  2   Avg_pending_calls      23 non-null     float64
#  3   Avg_resol_time         23 non-null     int64
#  4   recurrence_freq        23 non-null     float64
#  5   Replace_percent        23 non-null     float64
#  6   In_warranty_percent    23 non-null     int64
#  7   Post_warranty_percent  23 non-null     int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 1.6+ KB

# %%
df.shape
# Out:
# (23, 8)

# %%
df.columns
# Out:
# Index(['PROBLEM_TYPE', 'no_of_cases', 'Avg_pending_calls', 'Avg_resol_time',
#        'recurrence_freq', 'Replace_percent', 'In_warranty_percent',
#        'Post_warranty_percent'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PROBLEM_TYPE              object
# no_of_cases                int64
# Avg_pending_calls        float64
# Avg_resol_time             int64
# recurrence_freq          float64
# Replace_percent          float64
# In_warranty_percent        int64
# Post_warranty_percent      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# PROBLEM_TYPE             0
# no_of_cases              0
# Avg_pending_calls        0
# Avg_resol_time           0
# recurrence_freq          0
# Replace_percent          0
# In_warranty_percent      0
# Post_warranty_percent    0
# dtype: int64

# %%
from sklearn.cluster import KMeans
from scipy.stats import zscore

# %%
techsuppAttr = df.iloc[:,1:]
techsuppAttr
# Out:
#     no_of_cases  Avg_pending_calls  Avg_resol_time  recurrence_freq  \
# 0           170                1.3              32             0.04
# 1            12                2.0             150             0.01
# 2             5                1.0              35             0.02
# 3             3                2.0               8             0.01
# 4            45                2.3              54             0.15
# 5            47                3.1             132             0.30
# 6            12                4.0             154             0.02
# 7           165                1.2              32             0.03
# 8           321                1.0               5             0.21
# 9            22                3.3             140             0.14
# 10           23                4.3             143             0.21
# 11          230                1.3              23             0.02
# 12          193                1.2              33             0.03
# ...

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(techsuppAttr.corr(), annot = True, cbar = False, cmap = 'viridis')
plt.show()

# %%
data2 = techsuppAttr.apply(zscore)
data2
# Out:
#     no_of_cases  Avg_pending_calls  Avg_resol_time  recurrence_freq  \
# 0      0.179429          -0.701207       -0.538351        -0.843188
# 1     -0.862176           0.027143        1.510857        -1.101765
# 2     -0.908323          -1.013357       -0.486253        -1.015573
# 3     -0.921508           0.027143       -0.955140        -1.101765
# 4     -0.644625           0.339294       -0.156296         0.104930
# 5     -0.631441           1.171694        1.198266         1.397818
# 6     -0.862176           2.108144        1.580322        -1.015573
# 7      0.146467          -0.805257       -0.538351        -0.929380
# 8      1.174886          -1.013357       -1.007238         0.622085
# 9     -0.796251           1.379794        1.337195         0.018738
# 10    -0.789659           2.420294        1.389294         0.622085
# 11     0.574975          -0.701207       -0.694647        -1.015573
# 12     0.331055          -0.805257       -0.520985        -0.929380
# ...

# %%
plt.figure(figsize = (10, 8))
sns.pairplot(data2, diag_kind = 'kde') #this is more preferrable
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize = (10, 8))
sns.pairplot(data2)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from scipy.spatial.distance import cdist
clusters = range(1, 10)
meandistance = []
for k in clusters:
    model = KMeans(n_clusters = k)
    model.fit(data2)
    prediction = model.predict(data2)
    meandistance.append(sum(np.min(cdist(data2, model.cluster_centers_,'euclidean'), axis = 1))/data2.shape[0])
    

meandistance
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.plot(clusters, meandistance, 'bx-')
plt.xlabel("K")
plt.ylabel("Mean Distance")
plt.title("Selecting K with the Elbow Method")
plt.show()

# %%
finalmodel = KMeans(3)
finalmodel.fit(data2)
prediction = finalmodel.predict(data2)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df['cluster'] = prediction
df
# Out:
#                                  PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0             Temperature control not working          170                1.3
# 1            power chord does not tightly fit           12                2.0
# 2                       Fan swing not working            5                1.0
# 3                     Main switch does not on            3                2.0
# 4                  Forgot mobile app password           45                2.3
# 5                           AC stops abruptly           47                3.1
# 6            App hangs while entring commands           12                4.0
# 7         App takes a long time to initialize          165                1.2
# 8     Unable to connect the App to the device          321                1.0
# 9        Reinstalling the app hangs the phone           22                3.3
# 10       Mobile screen blanks on use of phone           23                4.3
# ...

# %%
df[df['cluster'] == 0]
# Out:
#                             PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 4             Forgot mobile app password           45                2.3
# 5                      AC stops abruptly           47                3.1
# 6       App hangs while entring commands           12                4.0
# 9   Reinstalling the app hangs the phone           22                3.3
# 10  Mobile screen blanks on use of phone           23                4.3
# 13              AC remote does not  work           24                2.8
# 18          Factory settings not working           72                2.3
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 4               54             0.15             0.00                   99
# 5              132             0.30             0.03                  100
# 6              154             0.02             0.05                  100
# 9              140             0.14             0.01                   95
# ...

# %%
df[df['cluster'] == 1]
# Out:
#                                PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0           Temperature control not working          170                1.3
# 2                     Fan swing not working            5                1.0
# 7       App takes a long time to initialize          165                1.2
# 8   Unable to connect the App to the device          321                1.0
# 12            AC controller sofware missing          193                1.2
# 14                   Remote Keys get stuck           450                1.0
# 15       Unable to operate menu from remote          520                1.0
# 17                   Freshner holder stuck           140                1.7
# 19                WIFI connectivity breaks           290                1.1
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0               32             0.04             0.00                   75
# ...
